# %% [markdown]
# # Mestrado em Inteligência Artificial 25/26
#
# # Practical 4 — TicTacToe
#
# Today we will implement the TicTacToe environment and a state feature encoder that we'll use next class to train a REINFORCE agent.
#
# First, let's see what a game looks like.
# **Note:** this cell requires your `TicTacToeEnv` TODOs to be complete.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../..'))

from mia_rl.envs.tictactoe import TicTacToeEnv
from mia_rl.policies.tictactoe import random_action
from mia_rl.experiments.tictactoe import play_game, play_game_vs_human

# %%
env = TicTacToeEnv()
play_game(env, random_action, random_action)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 env = TicTacToeEnv()
# ----> 2 play_game(env, random_action, random_action)
#
# File c:\Users\nunoa\Desktop\aulas\rl\miaRL\mia_rl\experiments\tictactoe.py:28, in play_game(env, policy_x, policy_o, render)
#      11 def play_game(
#      12     env: TicTacToeEnv,
#      13     policy_x: Policy,
#      14     policy_o: Policy,
#      15     render: bool = True,
#      16 ) -> int:
#      17     """Play one full game between two policies, optionally rendering each step.
#      18
#      19     Args:
#    (...)     26         1 if X wins, -1 if O wins, 0 for a draw.
#      27     """
# ---> 28     state = env.reset()
#      29     if render:
#      30         print("Initial board:")
#
# File c:\Users\nunoa\Desktop\aulas\rl\miaRL\mia_rl\envs\tictactoe.py:65, in TicTacToeEnv.reset(self)
#      57 def reset(self) -> TicTacToeState:
#      58     """Reset the board to an empty state and set X as the first player.
#      59
#      60     TODO:
#    (...)     63     3. Return the initial board state.
#      64     """
# ---> 65     raise NotImplementedError("TODO: implement reset.")
#
# NotImplementedError: TODO: implement reset.

# %%
# Play as O (-1) against a random agent — you'll be prompted to pick a cell.
play_game_vs_human(env, random_action, human_plays=-1)
